# %% [markdown]
# <a href="https://colab.research.google.com/github/saswanth01/DSA0303/blob/main/Activity_1_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
from collections import Counter

# Step 1: Read a small text corpus
corpus = """
Natural language processing is a branch of artificial intelligence.
Natural language processing helps computers understand human language.
Language models predict the next word in a sentence.
"""

# Step 2: Tokenize the text into words
tokens = re.findall(r'\b\w+\b', corpus.lower())

print("Tokens:")
print(tokens)

# Step 3: Generate unigram and bigram frequency counts
unigram_counts = Counter(tokens)

bigrams = [(tokens[i], tokens[i + 1]) for i in range(len(tokens) - 1)]
bigram_counts = Counter(bigrams)

print("\nUnigram Frequency Counts:")
for word, count in unigram_counts.items():
    print(f"{word}: {count}")

print("\nBigram Frequency Counts:")
for bigram, count in bigram_counts.items():
    print(f"{bigram}: {count}")

# Step 4: Compute unigram probabilities
total_words = len(tokens)

print("\nUnigram Probabilities:")
for word, count in unigram_counts.items():
    probability = count / total_words
    print(f"P({word}) = {probability:.4f}")

# Step 5: Compute bigram probabilities using MLE
print("\nBigram Probabilities (MLE):")
bigram_probabilities = {}

for (w1, w2), count in bigram_counts.items():
    probability = count / unigram_counts[w1]
    bigram_probabilities[(w1, w2)] = probability
    print(f"P({w2}|{w1}) = {probability:.4f}")

# Step 6 & 7: Check whether a given bigram exists
first = input("\nEnter the first word: ").lower()
second = input("Enter the second word: ").lower()

query = (first, second)

if query in bigram_probabilities:
    print(f"\nBigram {query} exists in the corpus.")
    print(f"Probability = {bigram_probabilities[query]:.4f}")
else:
    print(f"\nBigram {query} does not exist in the corpus.")
    print("Probability = 0.0000 (Zero Probability)")
# Out:
# Tokens:
# ['natural', 'language', 'processing', 'is', 'a', 'branch', 'of', 'artificial', 'intelligence', 'natural', 'language', 'processing', 'helps', 'computers', 'understand', 'human', 'language', 'language', 'models', 'predict', 'the', 'next', 'word', 'in', 'a', 'sentence']
#
# Unigram Frequency Counts:
# natural: 2
# language: 4
# processing: 2
# is: 1
# a: 2
# branch: 1
# of: 1
# artificial: 1
# intelligence: 1
# helps: 1
# computers: 1
# understand: 1
# human: 1
# models: 1
# predict: 1
# the: 1
# next: 1
# word: 1
# in: 1
# sentence: 1
#
# Bigram Frequency Counts:
# ('natural', 'language'): 2
# ('language', 'processing'): 2
# ('processing', 'is'): 1
# ('is', 'a'): 1
# ('a', 'branch'): 1
# ('branch', 'of'): 1
# ('of', 'artificial'): 1
# ('artificial', 'intelligence'): 1
# ('intelligence', 'natural'): 1
# ('processing', 'helps'): 1
# ('helps', 'computers'): 1
# ('computers', 'understand'): 1
# ('understand', 'human'): 1
# ('human', 'language'): 1
# ('language', 'language'): 1
# ...
