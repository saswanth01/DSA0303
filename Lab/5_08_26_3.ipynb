# %% [markdown]
# <a href="https://colab.research.google.com/github/saswanth01/DSA0303/blob/main/Lab/5_08_26_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk import word_tokenize, pos_tag

sentence = "Every student completed the assignment."

tokens = word_tokenize(sentence)
tags = pos_tag(tokens)

print(tags)
# Out:
# [('Every', 'DT'), ('student', 'NN'), ('completed', 'VBD'), ('the', 'DT'), ('assignment', 'NN'), ('.', '.')]
