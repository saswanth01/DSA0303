# %% [markdown]
# <a href="https://colab.research.google.com/github/saswanth01/DSA0303/blob/main/Lab/5_08_26_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk import word_tokenize, pos_tag

sentence = "Microsoft announced a new cloud platform."

tokens = word_tokenize(sentence)
tags = pos_tag(tokens)

print(tags)
# Out:
# [('Microsoft', 'NNP'), ('announced', 'VBD'), ('a', 'DT'), ('new', 'JJ'), ('cloud', 'NN'), ('platform', 'NN'), ('.', '.')]
