# %% [markdown]
# <a href="https://colab.research.google.com/github/saswanth01/DSA0303/blob/main/5_08_26_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk import word_tokenize, pos_tag

sentence = "The intelligent student quickly solved the problem."

tokens = word_tokenize(sentence)

tags = pos_tag(tokens)

print(tags)
# Out:
# [('The', 'DT'), ('intelligent', 'JJ'), ('student', 'NN'), ('quickly', 'RB'), ('solved', 'VBD'), ('the', 'DT'), ('problem', 'NN'), ('.', '.')]
